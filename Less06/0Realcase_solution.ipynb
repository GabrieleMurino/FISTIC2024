# %% [markdown]
# ## Real Case "SMALL DATA"

# %% [markdown]
# <img src='https://frenzy86.s3.eu-west-2.amazonaws.com/python/img/tom1.png' width=900>

# %% [markdown]
# <img src='https://frenzy86.s3.eu-west-2.amazonaws.com/python/img/tom2.png' width=900>

# %%
#!wget https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/realcase/dataset_costi.xlsx

#Target colonna "costi anno 2020"

# %%
path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/realcase/dataset_costi.xlsx'

# %% [markdown]
# <img src='https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/pandas_.png' width=500>

# %%
path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/realcase/dataset_costi.xlsx'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# %%
df = pd.read_excel('https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/realcase/dataset_costi.xlsx')
pd.set_option('display.max_columns', None)
df
# Out:
#       index Ragione sociale  costi anno 2020       var1       var2  var3  \
# 0       101      company101        144205134  147823139  148193655     0
# 1       102      company102        140165127  147562322  163251010     0
# 2       103      company103        145190000  147562000  142652000     0
# 3       104      company104        112760368  147067625  140160124     0
# 4       105      company105        171980718  145273739  127413305     0
# ...     ...             ...              ...        ...        ...   ...
# 7919   8020     company8020            81879       n.d.       n.d.     0
# 7920   8021     company8021            80757       n.d.       n.d.     0
# 7921   8022     company8022            74478       n.d.       n.d.  7000
# 7922   8023     company8023                0       n.d.       n.d.     0
# 7923   8024     company8024                0       n.d.     169365     0
#
#       var4  var5      var6      var7      var8      var9     var10     var11  \
# 0        0     0  51344312  61401789  71387976  23064675  20882011  14244395
# 1        0     0   1037776   1391301   1602930  23503659  22973259  20946238
# 2        0     0    737000    707000    745000  51250000  51604000  50992000
# 3        0     0     39316      5715      8015   5258584   5491288   5735791
# 4        0     0   6571906   3613836   3218188  65670888  56917531  51856050
# ...    ...   ...       ...       ...       ...       ...       ...       ...
# 7919  n.d.  n.d.      1500      n.d.      n.d.         0      n.d.      n.d.
# 7920  n.d.  n.d.      1500      n.d.      n.d.         0      n.d.      n.d.
# 7921  n.d.  n.d.      2529      n.d.      n.d.         0      n.d.      n.d.
# 7922  n.d.  n.d.         0      n.d.      n.d.  16295937      n.d.      n.d.
# 7923  n.d.     0    195790      n.d.    211773    735210      n.d.    943024
#
#          var12     var13     var14     var15     var16    var17    var18  \
# 0      2794279   2677799   2833077  14562964  14352577  8073273        0
# 1     13368527  12404318  11085331   1850794   1693511  1060485   364872
# 2     23900000  25404000  26269000     69000     66000    56000        0
# 3      4183889   4354175   4510666     25917     25917    25917    25917
# 4     20251827  20965972  20661743   2324116   2070401   179562  1754388
# ...        ...       ...       ...       ...       ...      ...      ...
# 7919         0      n.d.      n.d.         0      n.d.     n.d.        0
# 7920         0      n.d.      n.d.         0      n.d.     n.d.        0
# 7921         0      n.d.      n.d.         0      n.d.     n.d.        0
# 7922  16295937      n.d.      n.d.     39881      n.d.     n.d.     8252
# 7923      n.d.      n.d.      n.d.      5100      n.d.     8800        0
#
#         var19   var20    var21   var22   var23 var24 var25 var26     var27  \
# 0           0       0        0       0   73273     0     0     0   9312470
# 1     1287356  811956  1485922  406155  248529     0     0     0  34529004
# 2           0       0        0       0       0     0     0     0  17498000
# 3       25917   25917        0       0       0     0     0     0  25923161
# 4     1625505  178366        0    1196    1196     0     0     0  18950865
# ...       ...     ...      ...     ...     ...   ...   ...   ...       ...
# 7919        0       0        0       0       0     0  n.d.  n.d.         0
# 7920        0       0        0       0       0     0  n.d.  n.d.         0
# 7921        0       0        0       0       0     0  n.d.  n.d.     26100
# 7922        0       0    31629       0       0     0  n.d.  n.d.         0
# 7923        0       0        0       0       0  n.d.  n.d.  n.d.         0
#
#          var28     var29     var30     var31     var32     var33     var34  \
# 0      7915379   7272270  35436524  37191289  32749686  32719851  34723462
# 1     35683884  35340902  23391321  22915530  18886264  10795833  11017483
# 2     12270000  12954000  31359000  47731000  43044000  26022000  43298000
# 3     17921979  19627665  21948953  22868722  23881755  15584991  15576621
# 4     16878270  18797216   8362491  16303624  14624193   4425910  11432236
# ...        ...       ...       ...       ...       ...       ...       ...
# 7919      n.d.      n.d.    106391      n.d.      n.d.         0         0
# 7920      n.d.      n.d.     76547      n.d.      n.d.         0         0
# 7921      n.d.      n.d.     26659      n.d.      n.d.         0         0
# 7922      n.d.      n.d.   2392696      n.d.      n.d.     13965         0
# 7923      n.d.         0    245262      n.d.    236132         0         0
#
#          var35 var36 var37 var38    var39    var40    var41   var42    var43  \
# 0     30111298     0     0     0    84978   318158   318158       0        0
# 1     11177585  1583  1583  1588     1583     1583     1588  355977    43180
# 2     39653000     0     0     0  1801000  1761000  1171000    3000     3000
# 3     23831452     0     0     0   890646        0        0       0  2226616
# 4     11013435     0     0     0        0        0        0       0        0
# ...        ...   ...   ...   ...      ...      ...      ...     ...      ...
# 7919         0     0  n.d.  n.d.        0        0        0       0     n.d.
# 7920         0     0  n.d.  n.d.        0        0        0       0     n.d.
# 7921         0     0  n.d.  n.d.        0        0        0       0     n.d.
# 7922         0     0  n.d.  n.d.     5253        0        0       0     n.d.
# 7923         0     0  n.d.     0        0        0        0       0     n.d.
#
#        var44     var45     var46     var47    var48   var49   var50  \
# 0          0   7834908   2178851  18788146   290899  188430  570560
# 1     471450   5293624   2889766   1616895   408806  551290  687712
# 2          0  19082000   4224000   5958000  1596000    7000       0
# 3          0    185206     54173   1151195   643650  567191  677336
# 4          0  14381920  10465984  10529721  1463431  707312  527470
# ...      ...       ...       ...       ...      ...     ...     ...
# 7919    n.d.      7878      n.d.      n.d.     7380    n.d.    n.d.
# 7920    n.d.     44648      n.d.      n.d.        0    n.d.    n.d.
# 7921    n.d.      3175      n.d.      n.d.     2208    n.d.    n.d.
# 7922    n.d.       100      n.d.      n.d.    31907    n.d.    n.d.
# 7923       0     28915      n.d.     76769     1322    n.d.    3537
#
#           var51      var52      var53     var54     var55     var56     var57  \
# 0     141846752  144110326  153086306  69193271  72220512  85886434   4033074
# 1      90370961   88141721   80612876  21212948  18327864  16372048   9000000
# 2     121594000  116612000  113749000  24965000  25707000  23690000   5933000
# 3      54024787   49161601   51107674  11928401  11449946  10955620   1976000
# 4     117725617  106956958   99732400  15404312  14454587  13758507  12000000
# ...         ...        ...        ...       ...       ...       ...       ...
# 7919     123149       n.d.       n.d.     30614      n.d.      n.d.     10000
# 7920     122695       n.d.       n.d.     17905      n.d.      n.d.     10000
# 7921      67671       n.d.       n.d.      9331      n.d.      n.d.     10000
# 7922   18760521       n.d.       n.d.   3047157      n.d.      n.d.   5279220
# 7923    1211599       n.d.    1480035    310833      n.d.    430267     10200
#
#          var58     var59    var60    var61     var62   var63    var64  \
# 0      4033074   4033074  8874677  9644129  10513852  812758   940485
# 1      9000000   8000000   539412   878366   1154727  555689   586514
# 2      5933000   5933000  3915000  5536000   4253000  685000   804000
# 3      1976000   1976000        0        0         0  516863   536725
# 4     12000000  12000000   109050    91544     65522  896335  1298754
# ...        ...       ...      ...      ...       ...     ...      ...
# 7919      n.d.      n.d.        0     n.d.      n.d.       0     n.d.
# 7920      n.d.      n.d.        0     n.d.      n.d.       0     n.d.
# 7921      n.d.      n.d.        0     n.d.      n.d.     920     n.d.
# 7922      n.d.      n.d.        0     n.d.      n.d.       0     n.d.
# 7923      n.d.     10200    55000     n.d.     55000       0     n.d.
#
#         var65      var66     var67     var68     var69     var70     var71  \
# 0     1060351   62928609  61236117  54359909  25290616  24108358  24535319
# 1      594299   65207408  68150008  62242345  14133394  10404117  12898505
# 2      892000   91688000  84236000  84347000  31861000  22494000  24687000
# 3      575637   40609649  36404281  38672555   1000000         0   1188439
# 4     1071715  100872660  90771853  84482418  27325115  24037285  24492237
# ...       ...        ...       ...       ...       ...       ...       ...
# 7919     n.d.      92535      n.d.      n.d.         0      n.d.      n.d.
# 7920     n.d.     104790      n.d.      n.d.         0      n.d.      n.d.
# 7921     n.d.      57420      n.d.      n.d.         0      n.d.      n.d.
# 7922     n.d.   15703900      n.d.      n.d.    303714      n.d.      n.d.
# 7923        0     845706      n.d.    994711    489502      n.d.    646356
#
#          var72     var73     var74     var75     var76     var77     var78  \
# 0            0         0         0         0         0         0         0
# 1     29430949  39612215  32870407  14133394  10404117  12898505  29430949
# 2     24578000  25744000  21033000  31861000  22494000  24687000  24578000
# 3     26719881  24599616  25292061   1000000         0   1188439  26719881
# 4     32205485  32341802  30245665  27112282  23559197  23166222  32695485
# ...        ...       ...       ...       ...       ...       ...       ...
# 7919      n.d.      n.d.      n.d.         0      n.d.      n.d.         0
# 7920      n.d.      n.d.      n.d.         0      n.d.      n.d.         0
# 7921      n.d.      n.d.      n.d.         0      n.d.      n.d.         0
# 7922   1306367      n.d.      n.d.    303714      n.d.      n.d.   1306367
# 7923      n.d.      n.d.      n.d.      n.d.      n.d.      n.d.         0
#
#          var79     var80     var81     var82     var83     var84     var85  \
# 0       158005    154528         0         0    158005  29565517  29302779
# 1     39612215  32870407  14133394  10404117  12898505  16595959  12520527
# 2     29507000  25272000  31861000  22494000  24687000  32357000  28219000
# 3     24599616  25292061   1000000         0   1188439  10388151   9719252
# 4     32841802  30745665  27112282  23559197  23666222  38983227  32661501
# ...        ...       ...       ...       ...       ...       ...       ...
# 7919         0         0         0         0         0         0         0
# 7920         0         0         0         0         0         0         0
# 7921         0         0         0         0         0         0         0
# 7922         0         0    303714         0         0    294256         0
# 7923         0         0         0         0         0         0         0
#
#          var86   var87   var88   var89    var90   var91    var92      var93  \
# 0     22500461       0       0       0    37437   69083  1265760  145914503
# 1     13143079       0       0       0  2855504  198969   249457  142727898
# 2     30630000       0       0       0   341000  329000   567000  148757000
# 3     11365649       0       0       0   969874  770649   903862  119349203
# 4     28307414  212833  231169  249055   443260  340220   354238  174796438
# ...        ...     ...     ...     ...      ...     ...      ...        ...
# 7919         0       0       0       0        0    n.d.     n.d.     107884
# 7920         0       0       0       0        0    n.d.     n.d.     103290
# 7921         0       0       0       0        0    n.d.     n.d.     100745
# 7922         0       0       0       0     9464    n.d.     n.d.     557988
# 7923         0       0       0       0       60    n.d.       57     152400
#
#           var94      var95    var96    var97    var98      var99     var100  \
# 0     148992105  149021406  1135448  1033613   392038   85824629   86758885
# 1     150222876  166417107  2028227   778100  3166950  102237238  113037130
# 2     153783000  148906000  5273000  6221000  6157000  117422000  111227000
# 3     145528364  143260149   456101   472875   489105  105779603  129982682
# 4     148011089  130682792   331385   261630   455198  149110551  119058121
# ...         ...        ...      ...      ...      ...        ...        ...
# 7919       n.d.       n.d.    26005     n.d.     n.d.       9325       n.d.
# 7920       n.d.       n.d.    22533     n.d.     n.d.       5850       n.d.
# 7921       n.d.       n.d.      167     n.d.     n.d.      57496       n.d.
# 7922       n.d.       n.d.   557988     n.d.     n.d.          0       n.d.
# 7923       n.d.     298703   152400     n.d.   176590          0       n.d.
#
#          var101    var102    var103    var104   var105   var106   var107  \
# 0      83651116  30573391  27161965  27459901  1892059  1841524  1807968
# 1     131392006  11501816  11119691  13728039  1290053  1340018  1338016
# 2     108035000  21643000  19825000  18553000   199000   118000   180000
# 3     121831610  10515673  10102156  12005008    58016    55497    43112
# 4     106955719  11984035  11483667  11814301   417592   393338   542586
# ...         ...       ...       ...       ...      ...      ...      ...
# 7919       n.d.     26777      n.d.      n.d.     2500     n.d.     n.d.
# 7920       n.d.     36142      n.d.      n.d.     1300     n.d.     n.d.
# 7921       n.d.     12679      n.d.      n.d.     9587     n.d.     n.d.
# 7922       n.d.     27625      n.d.      n.d.        0     n.d.     n.d.
# 7923      57705     10574      n.d.     25554        0     n.d.        0
#
#         var108    var109    var110    var111    var112    var113   var114  \
# 0     13310780  13264428  12114005  14296757  13558421  13421133  -823170
# 1     16889643  15833127  15986500   2713441   2434423   2180861  3207072
# 2      9901000  10029000   9581000   3832000   3762000   3497000 -6933000
# 3      3075383   3296773   3290801    631775    638706    725484 -1868447
# 4      6335628   5294076   4974163   5310610   4361914   3345706 -2235901
# ...        ...       ...       ...       ...       ...       ...      ...
# 7919     38607      n.d.      n.d.       375      n.d.      n.d.        0
# 7920     46571      n.d.      n.d.       375      n.d.      n.d.        0
# 7921     20126      n.d.      n.d.       632      n.d.      n.d.        0
# 7922         0      n.d.      n.d.    705926      n.d.      n.d.        0
# 7923       439      n.d.     30024    106862      n.d.    107848        0
#
#        var115    var116  var117 var118  var119  var120 var121 var122   var123  \
# 0     -507756   -530593       0  46982  114473       0      0      0  1228034
# 1     1304536  -3015558       0      0  627379       0      0      0   912728
# 2      683000   2125000       0      0       0       0      0      0  2624000
# 3     -306450   3770484       0      0       0       0      0      0   421274
# 4     3075212  -2049351    7120   6398   25215       0      0      0  1676826
# ...       ...       ...     ...    ...     ...     ...    ...    ...      ...
# 7919     n.d.      n.d.       0   n.d.    n.d.       0   n.d.   n.d.      577
# 7920     n.d.      n.d.       0   n.d.    n.d.       0   n.d.   n.d.       18
# 7921     n.d.      n.d.       0   n.d.    n.d.       0   n.d.   n.d.      632
# 7922     n.d.      n.d.       0   n.d.    n.d.       0   n.d.   n.d.   243976
# 7923     n.d.         0       0   n.d.       0       0   n.d.      0   119433
#
#        var124   var125  var126  var127  var128   var129   var130   var131  \
# 0      977093  1122097  783131  572136  267603  1588604  1604455  1856974
# 1     1042592  1058524   80006   47390   35171   769967   895916  1201286
# 2     2743000  1937000   53000   59000   59000   915000  1122000  1153000
# 3      885471   377168  217482  149383  155720   428722   439358   525316
# 4     1524379  2270501   31436   12726   60454   781590   787832  1051073
# ...       ...      ...     ...     ...     ...      ...      ...      ...
# 7919     n.d.     n.d.       0       0       0       56     n.d.     n.d.
# 7920     n.d.     n.d.       2       0       0       70     n.d.     n.d.
# 7921     n.d.     n.d.       0       0       0      262     n.d.     n.d.
# 7922     n.d.     n.d.       0       0       0   641612     n.d.     n.d.
# 7923     n.d.    26812      12       0       1    11491     n.d.    16584
#
#       var132  var133   var134  var135 var136  var137  var138 var139 var140  \
# 0      36310  -66672   135970       0      0       0       0      0      0
# 1      11943   82820  1553908       0      0       0       0      0      0
# 2      -1000    3000   -10000       0      0  -36000       0      0      0
# 3      34150   95776  -114667       0      0       0       0      0      0
# 4       -481     -95     -697       0      0       0       0      0      0
# ...      ...     ...      ...     ...    ...     ...     ...    ...    ...
# 7919       0    n.d.     n.d.       0   n.d.    n.d.       0   n.d.   n.d.
# 7920       0    n.d.     n.d.       0   n.d.    n.d.       0   n.d.   n.d.
# 7921       0    n.d.     n.d.       0   n.d.    n.d.       0   n.d.   n.d.
# 7922       0    n.d.     n.d.       0   n.d.    n.d.       0   n.d.   n.d.
# 7923       0    n.d.        0       0   n.d.       0       0   n.d.      0
#
#        var141   var142   var143 var144 var145 var146   var147   var148  \
# 0     1870101  3257494  4594656   n.d.   n.d.   n.d. -3027241  1534078
# 1     1373420  1220932  1304576   n.d.   n.d.   n.d.  1924469  2124721
# 2        9000  1166000  1450000   n.d.   n.d.   n.d.  -803000  3170000
# 3       80381   185005   258220   n.d.   n.d.   n.d.   478455   494325
# 4      472994   795056   943092   n.d.   n.d.   n.d.   966348  1243727
# ...       ...      ...      ...    ...    ...    ...      ...      ...
# 7919     9054     n.d.     n.d.   n.d.   n.d.   n.d.    20613     n.d.
# 7920     5063     n.d.     n.d.   n.d.   n.d.   n.d.     7903     n.d.
# 7921        0     n.d.     n.d.   n.d.   n.d.   n.d.     -669     n.d.
# 7922   -25766     n.d.     n.d.   n.d.   n.d.   n.d. -1035385     n.d.
# 7923     3979     n.d.    10056   n.d.   n.d.   n.d.  -100366     n.d.
#
#        var149 var150 var151 var152 ATECO 2007\ncodice  \
# 0     3813249    229    214    207           zyx56973
# 1     2204557    454    411    456           zyx56974
# 2     2408000    116    165    168           zyx56975
# 3      473999     60     60     65           zyx56976
# 4      869544    171    141    132           zyx56977
# ...       ...    ...    ...    ...                ...
# 7919     n.d.     10   n.d.   n.d.           zyx64892
# 7920     n.d.     29   n.d.   n.d.           zyx64893
# 7921     n.d.      1   n.d.   n.d.           zyx64894
# 7922     n.d.      0   n.d.   n.d.           zyx64895
# 7923    24121      0   n.d.      9           zyx64896
#
#                 Indirizzo sede legale Indirizzo sede legale - Codice postale  \
# 0                          via abc112                                 abc445
# 1                          via abc113                                 abc446
# 2                          via abc114                                 abc447
# 3                          via abc115                                 abc448
# 4                          via abc116                                 abc449
# ...                               ...                                    ...
# 7919              VIA ENRICO TOTI, 22                                abc8364
# 7920              VIA ENRICO TOTI, 22                                abc8365
# 7921           VIA STEFANO CATTAFI, 7                                abc8366
# 7922  VIA JOHN FITZGERALD KENNEDY, 16                                abc8367
# 7923                  VIA WAGNER, SNC                                abc8368
#
#      Indirizzo sede legale - Comune              Provincia  \
# 0                          Nerviano                 Milano
# 1                            Milano                 Milano
# 2                   Valle Lomellina                  Pavia
# 3                       Spilamberto                 Modena
# 4                           Moretta                  Cuneo
# ...                             ...                    ...
# 7919                          Monza  Monza e della Brianza
# 7920                          Monza  Monza e della Brianza
# 7921           Santa Lucia del Mela                Messina
# 7922             Reggio nell'Emilia     Reggio nell'Emilia
# 7923          Isola di Capo Rizzuto                Crotone
#
#      Indirizzo sede legale - Regione  Numero CCIAA  Codice fiscale  \
# 0                          Lombardia         20680             256
# 1                          Lombardia         20681             257
# 2                          Lombardia         20682             258
# 3                     Emilia-Romagna         20683             259
# 4                           Piemonte         20684             260
# ...                              ...           ...             ...
# 7919                       Lombardia         28599            8175
# 7920                       Lombardia         28600            8176
# 7921                         Sicilia         28601            8177
# 7922                  Emilia-Romagna         28602            8178
# 7923                        Calabria         28603            8179
#
#       Partita IVA   var153   var154   var155    var156    var157    var158  \
# 0           10696    84978   318158   318158  25290616  24108358  24535319
# 1           10697     1583     1583     1588  14133394  10404117  12898505
# 2           10698  1801000  1761000  1171000  31861000  22494000  24687000
# 3           10699   890646        0        0   1000000         0   1188439
# 4           10700        0        0        0  27325115  24037285  24492237
# ...           ...      ...      ...      ...       ...       ...       ...
# 7919        18615        0     n.d.     n.d.         0      n.d.      n.d.
# 7920        18616        0     n.d.     n.d.         0      n.d.      n.d.
# 7921        18617        0     n.d.     n.d.         0      n.d.      n.d.
# 7922        18618     5253     n.d.     n.d.    303714      n.d.      n.d.
# 7923        18619        0     n.d.        0    489502      n.d.    646356
#
#      var159
# 0     Produ
# 1     Produ
# 2     Produ
# 3     Produ
# 4     Produ
# ...     ...
# 7919  Produ
# 7920  Produ
# 7921  Produ
# 7922  Produ
# 7923  Produ
#
# [7924 rows x 171 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7924 entries, 0 to 7923
# Columns: 171 entries, index to var159
# dtypes: int64(68), object(103)
# memory usage: 10.3+ MB

# %%
corr_matrix = df.corr()
corr_drop = corr_matrix[abs(corr_matrix) < 0.5].index
df_cleaned= df.drop(columns=corr_drop)
print(df_cleaned())
print(f"Colonne droppate:{corr_drop}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 corr_matrix = df.corr()
#       2 corr_drop = corr_matrix[abs(corr_matrix) < 0.5].index
#       3 df_cleaned= df.drop(columns=corr_drop)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'company101'
